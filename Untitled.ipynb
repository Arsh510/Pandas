0.408728  0.631143  0.063032  0.518034
# 1   0.155533  0.794570  0.128796  0.037879  0.809086
# 2   0.775988  0.906464  0.090309  0.417505  0.725767
# 3   0.178861  0.929164  0.195855  0.320206  0.111419
# 4   0.153999  0.479902  0.359833  0.102208  0.379163
# ..       ...       ...       ...       ...       ...
# 95  0.811806  0.799504  0.782318  0.578273  0.798488
# 96  0.837186  0.791316  0.286186  0.323173  0.295514
# 97  0.792694  0.414834  0.812616  0.800919  0.212152
# 98  0.275056  0.056777  0.415045  0.498864  0.766735
# 99  0.222127  0.875412  0.446806  0.540282  0.647539
#
# [100 rows x 5 columns]

# %%
df1[0][0] = 0.22222

# %%
df1
# Out:
#            0         1         2         3         4
# 0    0.22222  0.408728  0.631143  0.063032  0.518034
# 1   0.155533  0.794570  0.128796  0.037879  0.809086
# 2   0.775988  0.906464  0.090309  0.417505  0.725767
# 3   0.178861  0.929164  0.195855  0.320206  0.111419
# 4   0.153999  0.479902  0.359833  0.102208  0.379163
# ..       ...       ...       ...       ...       ...
# 95  0.811806  0.799504  0.782318  0.578273  0.798488
# 96  0.837186  0.791316  0.286186  0.323173  0.295514
# 97  0.792694  0.414834  0.812616  0.800919  0.212152
# 98  0.275056  0.056777  0.415045  0.498864  0.766735
# 99  0.222127  0.875412  0.446806  0.540282  0.647539
#
# [100 rows x 5 columns]

# %%
df
# Out:
#            0         1         2         3         4
# 0    0.22222  0.408728  0.631143  0.063032  0.518034
# 1   0.155533  0.794570  0.128796  0.037879  0.809086
# 2   0.775988  0.906464  0.090309  0.417505  0.725767
# 3   0.178861  0.929164  0.195855  0.320206  0.111419
# 4   0.153999  0.479902  0.359833  0.102208  0.379163
# ..       ...       ...       ...       ...       ...
# 95  0.811806  0.799504  0.782318  0.578273  0.798488
# 96  0.837186  0.791316  0.286186  0.323173  0.295514
# 97  0.792694  0.414834  0.812616  0.800919  0.212152
# 98  0.275056  0.056777  0.415045  0.498864  0.766735
# 99  0.222127  0.875412  0.446806  0.540282  0.647539
#
# [100 rows x 5 columns]

# %%
df2 = df.copy()

# %%
df2[0][0] = 0.11111111
# Out:
# C:\Users\arsh patel\AppData\Local\Temp\ipykernel_23352\971675592.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[0][0] = 0.11111111

# %%
df2
# Out:
#            0         1         2         3         4
# 0   0.111111  0.408728  0.631143  0.063032  0.518034
# 1   0.155533  0.794570  0.128796  0.037879  0.809086
# 2   0.775988  0.906464  0.090309  0.417505  0.725767
# 3   0.178861  0.929164  0.195855  0.320206  0.111419
# 4   0.153999  0.479902  0.359833  0.102208  0.379163
# ..       ...       ...       ...       ...       ...
# 95  0.811806  0.799504  0.782318  0.578273  0.798488
# 96  0.837186  0.791316  0.286186  0.323173  0.295514
# 97  0.792694  0.414834  0.812616  0.800919  0.212152
# 98  0.275056  0.056777  0.415045  0.498864  0.766735
# 99  0.222127  0.875412  0.446806  0.540282  0.647539
#
# [100 rows x 5 columns]

# %%
df
# Out:
#            0         1         2         3         4
# 0    0.22222  0.408728  0.631143  0.063032  0.518034
# 1   0.155533  0.794570  0.128796  0.037879  0.809086
# 2   0.775988  0.906464  0.090309  0.417505  0.725767
# 3   0.178861  0.929164  0.195855  0.320206  0.111419
# 4   0.153999  0.479902  0.359833  0.102208  0.379163
# ..       ...       ...       ...       ...       ...
# 95  0.811806  0.799504  0.782318  0.578273  0.798488
# 96  0.837186  0.791316  0.286186  0.323173  0.295514
# 97  0.792694  0.414834  0.812616  0.800919  0.212152
# 98  0.275056  0.056777  0.415045  0.498864  0.766735
# 99  0.222127  0.875412  0.446806  0.540282  0.647539
#
# [100 rows x 5 columns]

# %%
df.loc[0,0] = 222

# %%
df.head()
# Out:
#           0         1         2         3         4
# 0       222  0.408728  0.631143  0.063032  0.518034
# 1  0.155533  0.794570  0.128796  0.037879  0.809086
# 2  0.775988  0.906464  0.090309  0.417505  0.725767
# 3  0.178861  0.929164  0.195855  0.320206  0.111419
# 4  0.153999  0.479902  0.359833  0.102208  0.379163

# %%
df.columns = list("ABCDE")

# %%
df.head(2)
# Out:
#           A         B         C         D         E
# 0       222  0.408728  0.631143  0.063032  0.518034
# 1  0.155533  0.794570  0.128796  0.037879  0.809086

# %%
df.loc[0,'A'] = 12345

# %%
df
# Out:
#            A         B         C         D         E
# 0      12345  0.408728  0.631143  0.063032  0.518034
# 1   0.155533  0.794570  0.128796  0.037879  0.809086
# 2   0.775988  0.906464  0.090309  0.417505  0.725767
# 3   0.178861  0.929164  0.195855  0.320206  0.111419
# 4   0.153999  0.479902  0.359833  0.102208  0.379163
# ..       ...       ...       ...       ...       ...
# 95  0.811806  0.799504  0.782318  0.578273  0.798488
# 96  0.837186  0.791316  0.286186  0.323173  0.295514
# 97  0.792694  0.414834  0.812616  0.800919  0.212152
# 98  0.275056  0.056777  0.415045  0.498864  0.766735
# 99  0.222127  0.875412  0.446806  0.540282  0.647539
#
# [100 rows x 5 columns]

# %%
df.loc[0,0] = 123

# %%
df.head()
# Out:
#           A         B         C         D         E      0
# 0     12345  0.408728  0.631143  0.063032  0.518034  123.0
# 1  0.155533  0.794570  0.128796  0.037879  0.809086    NaN
# 2  0.775988  0.906464  0.090309  0.417505  0.725767    NaN
# 3  0.178861  0.929164  0.195855  0.320206  0.111419    NaN
# 4  0.153999  0.479902  0.359833  0.102208  0.379163    NaN

# %%
df.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0.128796  0.037879
# 2  0.090309  0.417505

# %%
df.loc[(df['A']<0.2)]
# Out:
#            A         B         C         D         E   0
# 1   0.155533  0.794570  0.128796  0.037879  0.809086 NaN
# 3   0.178861  0.929164  0.195855  0.320206  0.111419 NaN
# 4   0.153999  0.479902  0.359833  0.102208  0.379163 NaN
# 5    0.04229  0.515183  0.700045  0.989739  0.651191 NaN
# 26  0.043261  0.835738  0.059514  0.350570  0.193811 NaN
# 28  0.070785  0.559225  0.439406  0.237688  0.983242 NaN
# 30  0.125451  0.544961  0.705687  0.459253  0.249996 NaN
# 34  0.035678  0.826556  0.372127  0.490909  0.610758 NaN
# 39  0.175859  0.268407  0.127196  0.640433  0.622588 NaN
# 41  0.082452  0.339008  0.432520  0.061625  0.724194 NaN
# 43   0.14206  0.710062  0.872696  0.660802  0.808617 NaN
# 45  0.152575  0.324266  0.959388  0.354048  0.604398 NaN
# 50  0.125406  0.408832  0.767481  0.380917  0.602502 NaN
# 51  0.175205  0.483798  0.741474  0.315284  0.340393 NaN
# 53  0.086652  0.894062  0.939594  0.826830  0.027160 NaN
# ...

# %%
df.head()
# Out:
#           A         B         C         D         E      0
# 0     12345  0.408728  0.631143  0.063032  0.518034  123.0
# 1  0.155533  0.794570  0.128796  0.037879  0.809086    NaN
# 2  0.775988  0.906464  0.090309  0.417505  0.725767    NaN
# 3  0.178861  0.929164  0.195855  0.320206  0.111419    NaN
# 4  0.153999  0.479902  0.359833  0.102208  0.379163    NaN

# %%
df.loc[(df['A']<0.2)]
# Out:
#            A         B         C         D         E   0
# 1   0.155533  0.794570  0.128796  0.037879  0.809086 NaN
# 3   0.178861  0.929164  0.195855  0.320206  0.111419 NaN
# 4   0.153999  0.479902  0.359833  0.102208  0.379163 NaN
# 5    0.04229  0.515183  0.700045  0.989739  0.651191 NaN
# 26  0.043261  0.835738  0.059514  0.350570  0.193811 NaN
# 28  0.070785  0.559225  0.439406  0.237688  0.983242 NaN
# 30  0.125451  0.544961  0.705687  0.459253  0.249996 NaN
# 34  0.035678  0.826556  0.372127  0.490909  0.610758 NaN
# 39  0.175859  0.268407  0.127196  0.640433  0.622588 NaN
# 41  0.082452  0.339008  0.432520  0.061625  0.724194 NaN
# 43   0.14206  0.710062  0.872696  0.660802  0.808617 NaN
# 45  0.152575  0.324266  0.959388  0.354048  0.604398 NaN
# 50  0.125406  0.408832  0.767481  0.380917  0.602502 NaN
# 51  0.175205  0.483798  0.741474  0.315284  0.340393 NaN
# 53  0.086652  0.894062  0.939594  0.826830  0.027160 NaN
# ...

# %%
df.head(2)
# Out:
#           A         B         C         D         E      0
# 0     12345  0.408728  0.631143  0.063032  0.518034  123.0
# 1  0.155533  0.794570  0.128796  0.037879  0.809086    NaN

# %%
df.iloc[0,4]
# Out:
# 0.5180337775711229

# %%
df.drop([1,5],axis=0, inplace=True)

# %%
df.head(3)
# Out:
#           A         B         C         D         E      0
# 0     12345  0.408728  0.631143  0.063032  0.518034  123.0
# 2  0.775988  0.906464  0.090309  0.417505  0.725767    NaN
# 3  0.178861  0.929164  0.195855  0.320206  0.111419    NaN

# %%
df.reset_index()
# Out:
#     index         A         B         C         D         E      0
# 0       0     12345  0.408728  0.631143  0.063032  0.518034  123.0
# 1       2  0.775988  0.906464  0.090309  0.417505  0.725767    NaN
# 2       3  0.178861  0.929164  0.195855  0.320206  0.111419    NaN
# 3       4  0.153999  0.479902  0.359833  0.102208  0.379163    NaN
# 4       6  0.796129  0.367002  0.767199  0.476317  0.577551    NaN
# ..    ...       ...       ...       ...       ...       ...    ...
# 93     95  0.811806  0.799504  0.782318  0.578273  0.798488    NaN
# 94     96  0.837186  0.791316  0.286186  0.323173  0.295514    NaN
# 95     97  0.792694  0.414834  0.812616  0.800919  0.212152    NaN
# 96     98  0.275056  0.056777  0.415045  0.498864  0.766735    NaN
# 97     99  0.222127  0.875412  0.446806  0.540282  0.647539    NaN
#
# [98 rows x 7 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#            A         B         C         D         E      0
# 0      12345  0.408728  0.631143  0.063032  0.518034  123.0
# 1   0.775988  0.906464  0.090309  0.417505  0.725767    NaN
# 2   0.178861  0.929164  0.195855  0.320206  0.111419    NaN
# 3   0.153999  0.479902  0.359833  0.102208  0.379163    NaN
# 4   0.796129  0.367002  0.767199  0.476317  0.577551    NaN
# ..       ...       ...       ...       ...       ...    ...
# 93  0.811806  0.799504  0.782318  0.578273  0.798488    NaN
# 94  0.837186  0.791316  0.286186  0.323173  0.295514    NaN
# 95  0.792694  0.414834  0.812616  0.800919  0.212152    NaN
# 96  0.275056  0.056777  0.415045  0.498864  0.766735    NaN
# 97  0.222127  0.875412  0.446806  0.540282  0.647539    NaN
#
# [98 rows x 6 columns]

# %%
df.loc[:, 'B'] = 0

# %%
df.head()
# Out:
#           A  B         C         D         E      0
# 0     12345  0  0.631143  0.063032  0.518034  123.0
# 1  0.775988  0  0.090309  0.417505  0.725767    NaN
# 2  0.178861  0  0.195855  0.320206  0.111419    NaN
# 3  0.153999  0  0.359833  0.102208  0.379163    NaN
# 4  0.796129  0  0.767199  0.476317  0.577551    NaN

# %%
dframe = pd.DataFrame(np.random.randint(1,50,size=(3,2)))

# %%
dframe
# Out:
#     0   1
# 0  21  37
# 1  28  44
# 2  17  44

# %%
dframe.describe()
# Out:
#                0          1
# count   3.000000   3.000000
# mean   22.000000  41.666667
# std     5.567764   4.041452
# min    17.000000  37.000000
# 25%    19.000000  40.500000
# 50%    21.000000  44.000000
# 75%    24.500000  44.000000
# max    28.000000  44.000000

# %%
dframe.mean()
# Out:
# 0    22.000000
# 1    41.666667
# dtype: float64

# %%
dframe.corr()
# Out:
#           0         1
# 0  1.000000  0.155543
# 1  0.155543  1.000000

# %%
dframe.count()
# Out:
# 0    3
# 1    3
# dtype: int64

# %%
dframe.max()
# Out:
# 0    28
# 1    44
# dtype: int32

# %%
dframe.min()
# Out:
# 0    17
# 1    37
# dtype: int32

# %%
dframe.median()
# Out:
# 0    21.0
# 1    44.0
# dtype: float64

# %%
df.std()
# Out:
# A    1246.984725
# B       0.000000
# C       0.295936
# D       0.281447
# E       0.254960
# 0            NaN
# dtype: float64

# %%
data = pd.read_excel('expdata.xlsx', sheet_name='Sheet2')

# %%
data
# Out:
#   name  Enroll subject
# 0    e       1     MAD
# 1    f       4      DS
# 2    g       8      WD
# 3    d       9      ML

# %%
data.iloc[0,0] = 'i'

# %%
data
# Out:
#   name  Enroll subject
# 0    i       1     MAD
# 1    f       4      DS
# 2    g       8      WD
# 3    d       9      ML

# %%
data.to_excel('expdata.xlsx', sheet_name='Sheet2')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [64], in <module>
# ----> 1 data.to_excel('expdata.xlsx', sheet_name='Sheet2')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:2357, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2344 from pandas.io.formats.excel import ExcelFormatter
#    2346 formatter = ExcelFormatter(
#    2347     df,
#    2348     na_rep=na_rep,
#    (...)
#    2355     inf_rep=inf_rep,
#    2356 )
# -> 2357 formatter.write(
#    2358     excel_writer,
#    2359     sheet_name=sheet_name,
#    2360     startrow=startrow,
#    2361     startcol=startcol,
#    2362     freeze_panes=freeze_panes,
#    2363     engine=engine,
# ...
